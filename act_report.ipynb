# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ### MOST POPULAR DOG NAME

# %% [markdown]
# ![Most_popular_dog_name.jpg](attachment:Most_popular_dog_name.jpg)

# %% [markdown]
# * From the graph we observed there are a lot of dog names but we focused on the most popular ones
# * I depicted this on the graph on a bar plot to help give a more detail view.
# * From the graph we can observe that the most tweeted dog name is Charlie.
# * Charlie was tweeted 12 times with the highest frequency.
# * This was followed on a tie by Lucy, Cooper and Oliver with 11 times.
# * There was another tie with regards to the other dog names which follows subsequently.
# * Tucker, Lola and Penny followed after the previous tie with 10 tweets
# * Winston and Bo with 9 tweets also had a tie with 9 tweets.
# * Sadie with 8 tweet ended the chart as the dog name with the least tweets.

# %% [markdown]
# ![Most_used_twitter_source.jpg](attachment:Most_used_twitter_source.jpg)

# %% [markdown]
# * Tweets are made and gotten from numerous sources
# * From our dataset we observe there were four sources of these tweets.
# * These sources are namely Twitter for Iphone, Vine - make a scene, Twitter web client and TweetDeck
# * From the dataset we wanted to find out the source most of the tweets come from
# * This would help give an overview of the most popular channels people tweet from.
# * From the graph we realize the most source of tweets is Twitter for Iphone.
# * This led the chart with 1436 tweets.
# * This makes it the most popular source of tweets looking at the huge gap between the second most popular source.
# * Vine - Make a scen comes up next with 41 tweets.
# * Twitter Web client follows with 16 tweets.
# * TweetDeck is the least among the sources of tweets

# %% [markdown]
# ![trend_plot.jpg](attachment:trend_plot.jpg)

# %% [markdown]
# *	The general outlook of the analysis depicts a downward trend
# *	There was a steep decline between January and March 2016
# *	There was a marginal upward growth from March 2016 but fell during May 2016.
# *	May 2016 and June 2016 saw an upward growth whuich declined in September.
# *	I observed a steady and lateral growth between September and October 2016.
# *	I observed a bit more upward growth growth but fell heading to January 2017.
# *	Growth fell between March 2017 through to May 2017, grew a bit and ended with a sharp decline in August 2017

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'act_report.ipynb'])
# Out:
# 0
